# %%
#!pip install ultralytics

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from ultralytics import YOLO
#model = YOLO("https://huggingface.co/Autsadin/yolov8-face/resolve/main/yolov8n-face.pt")
model= YOLO("yolov8n-face.pt")

# %% [markdown]
# ### image

# %%
def flouter(img):
    results = model(
        frame,
        conf=0.15,
        iou=0.45,
        imgsz=928,
        verbose=False
    )
    blurred = cv2.GaussianBlur(img, (99, 99), 30)
    mask = np.zeros(img.shape[:2], dtype=np.uint8)

    for box in results[0].boxes.xyxy.cpu().numpy():
        x1, y1, x2, y2 = map(int, box)
        cx = (x1 + x2) // 2
        cy = (y1 + y2) // 2
        radius = max(x2 - x1, y2 - y1) // 2
        cv2.circle(mask, (cx, cy), radius, 255, -1)
    #cv2.imwrite("image_floutee.jpg", img)
    img[mask == 255] = blurred[mask == 255]
    return img

# %%
img = cv2.imread("3.jpg")
flouter(img)
cv2.namedWindow("image", cv2.WINDOW_NORMAL)
cv2.imshow("image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 448x640 7 faces, 226.2ms
# Speed: 15.5ms preprocess, 226.2ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
cap = cv2.VideoCapture("lambo.mp4")
#fps    = cap.get(cv2.CAP_PROP_FPS)

#fourcc = cv2.VideoWriter_fourcc(*'mp4v')
#out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

print("Traitement + streaming en cours...")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    flouter(frame)

            

    # STREAMING AFFICHAGE
   # cv2.imshow("Video en streaming", frame)
    cv2.namedWindow("image", cv2.WINDOW_NORMAL)
    cv2.imshow("image", frame)
    # écriture fichier
    #out.write(frame)

    # quitter avec 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
#out.release()qq
cv2.destroyAllWindows()

#print(f"Terminé : {output_path}")
# Out:
# Traitement + streaming en cours...
#
# 0: 384x640 4 faces, 203.0ms
# Speed: 6.2ms preprocess, 203.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 199.9ms
# Speed: 12.3ms preprocess, 199.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 189.7ms
# Speed: 3.3ms preprocess, 189.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 151.2ms
# Speed: 3.7ms preprocess, 151.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 132.5ms
# Speed: 3.7ms preprocess, 132.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 139.0ms
# Speed: 3.6ms preprocess, 139.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 133.3ms
# Speed: 3.6ms preprocess, 133.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 162.7ms
# Speed: 3.6ms preprocess, 162.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 138.2ms
# Speed: 4.6ms preprocess, 138.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 137.4ms
# Speed: 3.2ms preprocess, 137.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 132.2ms
# Speed: 3.5ms preprocess, 132.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 faces, 201.8ms
# Speed: 3.7ms preprocess, 201.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 faces, 205.5ms
# Speed: 4.7ms preprocess, 205.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 faces, 177.5ms
# Speed: 3.7ms preprocess, 177.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 139.7ms
# Speed: 4.0ms preprocess, 139.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 148.3ms
# Speed: 4.8ms preprocess, 148.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 160.9ms
# Speed: 3.4ms preprocess, 160.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 faces, 132.6ms
# Speed: 4.2ms preprocess, 132.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 164.1ms
# Speed: 3.4ms preprocess, 164.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 187.4ms
# Speed: 3.5ms preprocess, 187.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces,